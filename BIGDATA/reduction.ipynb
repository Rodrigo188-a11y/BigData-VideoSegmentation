# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from PIL import Image
from matplotlib import cm

# %%
nameVideo = "giro2017_08.avi"
nameVideo = nameVideo.split(".")
extension = "." + nameVideo[1]
nameVideo = nameVideo[0]

# %%
cur_dir = os.getcwd()
def FormatingPicture():
    sucess, frame = video.read()
    if(sucess):
        frame = cv2.resize(frame,(224,224))
        cv2.imshow("Frames", frame)
        cv2.imwrite("./"+ nameVideo +"/Frames/frame"+str(currentframe)+".jpg", frame)
    return sucess,frame

# %%
video = cv2.VideoCapture(nameVideo + extension)
currentframe = 0

if not os.path.exists(nameVideo + "/Frames" ):
    os.makedirs(nameVideo +"/Frames" )

# %%
sucess = True
while(sucess):

    
    sucess, frame = FormatingPicture()
    if(sucess):
        print(frame.shape)
        currentframe+=1
    
    else:
        break
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
    
video.release()
cv2.destroyAllWindows()
# Out:
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# ...
